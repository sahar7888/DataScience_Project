# %% [markdown]
# <a href="https://colab.research.google.com/github/sahar7888/DataScience_Project/blob/main/Project_Deployed_On_Azure.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Campus Placement Predictor**

# %%
import pandas as pd
import numpy as np
import seaborn as sn
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('Placement_Data_Full_Class.csv')
df.head()
# Out:
#    sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1      2      M  79.33  Central  78.33   Others   Science     77.48
# 2      3      M  65.00  Central  68.00  Central      Arts     64.00
# 3      4      M  56.00  Central  52.00  Central   Science     52.00
# 4      5      M  85.80  Central  73.60  Central  Commerce     73.30
#
#     degree_t workex  etest_p specialisation  mba_p      status    salary
# 0   Sci&Tech     No     55.0         Mkt&HR  58.80      Placed  270000.0
# 1   Sci&Tech    Yes     86.5        Mkt&Fin  66.28      Placed  200000.0
# 2  Comm&Mgmt     No     75.0        Mkt&Fin  57.80      Placed  250000.0
# 3   Sci&Tech     No     66.0         Mkt&HR  59.43  Not Placed       NaN
# 4  Comm&Mgmt     No     96.8        Mkt&Fin  55.50      Placed  425000.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sl_no           215 non-null    int64
#  1   gender          215 non-null    object
#  2   ssc_p           215 non-null    float64
#  3   ssc_b           215 non-null    object
#  4   hsc_p           215 non-null    float64
#  5   hsc_b           215 non-null    object
#  6   hsc_s           215 non-null    object
#  7   degree_p        215 non-null    float64
#  8   degree_t        215 non-null    object
#  9   workex          215 non-null    object
#  10  etest_p         215 non-null    float64
#  11  specialisation  215 non-null    object
#  12  mba_p           215 non-null    float64
#  13  status          215 non-null    object
#  14  salary          148 non-null    float64
# dtypes: float64(6), int64(1), object(8)
# memory usage: 25.3+ KB

# %%
# seperating the categorical and numerical columns

catvars = list(df.select_dtypes(include=['object']).columns)

numvars = list(df.select_dtypes(include=['int32','int64','float32','float64']).columns)


print(catvars,numvars)
# Out:
# ['gender', 'ssc_b', 'hsc_b', 'hsc_s', 'degree_t', 'workex', 'specialisation', 'status'] ['sl_no', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary']

# %%
df.isnull().sum()
# Out:
# sl_no              0
# gender             0
# ssc_p              0
# ssc_b              0
# hsc_p              0
# hsc_b              0
# hsc_s              0
# degree_p           0
# degree_t           0
# workex             0
# etest_p            0
# specialisation     0
# mba_p              0
# status             0
# salary            67
# dtype: int64

# %% [markdown]
# ### Handling Null values

# %%
df.shape
# Out:
# (215, 15)

# %%
def plotdistplot(col):

    plt.figure(figsize=(15,7))
    sn.distplot(df['salary'],kde=True,hist=False,label='Actual Salary',color='orange')
    sn.distplot(df[col],kde=True,hist=False,label=col,color='black')

# %%
mostfreq = list(dict(df['salary'].value_counts()).items())[0]
mostfreq
# Out:
# (300000.0, 22)

# %%
df['salary'].mode()[0]
# Out:
# 300000.0

# %%
df['salary_mean'] = df['salary'].fillna(df['salary'].mean())
df['salary_median'] = df['salary'].fillna(df['salary'].median())
df['salary_mode'] = df['salary'].fillna(df['salary'].mode()[0])
df.head()
# Out:
#    sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1      2      M  79.33  Central  78.33   Others   Science     77.48
# 2      3      M  65.00  Central  68.00  Central      Arts     64.00
# 3      4      M  56.00  Central  52.00  Central   Science     52.00
# 4      5      M  85.80  Central  73.60  Central  Commerce     73.30
#
#     degree_t workex  etest_p specialisation  mba_p      status    salary  \
# 0   Sci&Tech     No     55.0         Mkt&HR  58.80      Placed  270000.0
# 1   Sci&Tech    Yes     86.5        Mkt&Fin  66.28      Placed  200000.0
# 2  Comm&Mgmt     No     75.0        Mkt&Fin  57.80      Placed  250000.0
# 3   Sci&Tech     No     66.0         Mkt&HR  59.43  Not Placed       NaN
# 4  Comm&Mgmt     No     96.8        Mkt&Fin  55.50      Placed  425000.0
#
#      salary_mean  salary_median  salary_mode
# 0  270000.000000       270000.0     270000.0
# 1  200000.000000       200000.0     200000.0
# 2  250000.000000       250000.0     250000.0
# 3  288655.405405       265000.0     300000.0
# 4  425000.000000       425000.0     425000.0

# %%
sallist = ['salary_mean','salary_median','salary_mode']
for sal in sallist:
    plotdistplot(sal)
# Out:
# <ipython-input-7-9539f51cadd5>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df['salary'],kde=True,hist=False,label='Actual Salary',color='orange')
# <ipython-input-7-9539f51cadd5>:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df[col],kde=True,hist=False,label=col,color='black')
# <ipython-input-7-9539f51cadd5>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df['salary'],kde=True,hist=False,label='Actual Salary',color='orange')
# <ipython-input-7-9539f51cadd5>:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df[col],kde=True,hist=False,label=col,color='black')
# <ipython-input-7-9539f51cadd5>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df['salary'],kde=True,hist=False,label='Actual Salary',color='orange')
# <ipython-input-7-9539f51cadd5>:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df[col],kde=True,hist=False,label=col,color='black')

# %%
# filling the salary with mean

df['salary'] = df['salary'].fillna(df['salary'].mean())
df.head()
# Out:
#    sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1      2      M  79.33  Central  78.33   Others   Science     77.48
# 2      3      M  65.00  Central  68.00  Central      Arts     64.00
# 3      4      M  56.00  Central  52.00  Central   Science     52.00
# 4      5      M  85.80  Central  73.60  Central  Commerce     73.30
#
#     degree_t workex  etest_p specialisation  mba_p      status         salary  \
# 0   Sci&Tech     No     55.0         Mkt&HR  58.80      Placed  270000.000000
# 1   Sci&Tech    Yes     86.5        Mkt&Fin  66.28      Placed  200000.000000
# 2  Comm&Mgmt     No     75.0        Mkt&Fin  57.80      Placed  250000.000000
# 3   Sci&Tech     No     66.0         Mkt&HR  59.43  Not Placed  288655.405405
# 4  Comm&Mgmt     No     96.8        Mkt&Fin  55.50      Placed  425000.000000
#
#      salary_mean  salary_median  salary_mode
# 0  270000.000000       270000.0     270000.0
# 1  200000.000000       200000.0     200000.0
# 2  250000.000000       250000.0     250000.0
# 3  288655.405405       265000.0     300000.0
# 4  425000.000000       425000.0     425000.0

# %%
df = df.drop(columns=['salary_mean', 'salary_median', 'salary_mode'],axis=1)
df.isnull().sum()
# Out:
# sl_no             0
# gender            0
# ssc_p             0
# ssc_b             0
# hsc_p             0
# hsc_b             0
# hsc_s             0
# degree_p          0
# degree_t          0
# workex            0
# etest_p           0
# specialisation    0
# mba_p             0
# status            0
# salary            0
# dtype: int64

# %% [markdown]
# # EDA

# %%
sn.countplot(df['status'],palette='plasma')
# Out:
# <ipython-input-14-b37068212798>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sn.countplot(df['status'],palette='plasma')
# <Axes: xlabel='count', ylabel='status'>

# %%
import seaborn as sn
import matplotlib.pyplot as plt

def valuecount(col):
    return dict(df[col].value_counts())

def getcountplot(col):
    sn.countplot(df[col], palette='plasma')
    # Changed rotation value to an integer
    plt.xticks(rotation=45, fontweight='bold', fontsize='10')
    plt.yticks(rotation=45, fontweight='bold', fontsize='10')
    plt.show()

for col in catvars:
    print(f'Count Plot for feature {col} is shown ↓')
    getcountplot(col)
    print('=' * 75)
# Out:
# Count Plot for feature gender is shown ↓
# <ipython-input-16-2908c6d2a329>:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sn.countplot(df[col], palette='plasma')
# ===========================================================================
# Count Plot for feature ssc_b is shown ↓
# <ipython-input-16-2908c6d2a329>:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sn.countplot(df[col], palette='plasma')
# ===========================================================================
# Count Plot for feature hsc_b is shown ↓
# <ipython-input-16-2908c6d2a329>:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sn.countplot(df[col], palette='plasma')
# ===========================================================================
# Count Plot for feature hsc_s is shown ↓
# <ipython-input-16-2908c6d2a329>:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sn.countplot(df[col], palette='plasma')
# ===========================================================================
# Count Plot for feature degree_t is shown ↓
# <ipython-input-16-2908c6d2a329>:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sn.countplot(df[col], palette='plasma')
# ===========================================================================
# Count Plot for feature workex is shown ↓
# <ipython-input-16-2908c6d2a329>:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sn.countplot(df[col], palette='plasma')
# ===========================================================================
# Count Plot for feature specialisation is shown ↓
# <ipython-input-16-2908c6d2a329>:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sn.countplot(df[col], palette='plasma')
# ===========================================================================
# Count Plot for feature status is shown ↓
# <ipython-input-16-2908c6d2a329>:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sn.countplot(df[col], palette='plasma')
# ===========================================================================

# %%
getfinaldict = {}
for col in catvars:
    getfinaldict[col] = valuecount(col)

getfinaldict
# Out:
# {'gender': {'M': 139, 'F': 76},
#  'ssc_b': {'Central': 116, 'Others': 99},
#  'hsc_b': {'Others': 131, 'Central': 84},
#  'hsc_s': {'Commerce': 113, 'Science': 91, 'Arts': 11},
#  'degree_t': {'Comm&Mgmt': 145, 'Sci&Tech': 59, 'Others': 11},
#  'workex': {'No': 141, 'Yes': 74},
#  'specialisation': {'Mkt&Fin': 120, 'Mkt&HR': 95},
#  'status': {'Placed': 148, 'Not Placed': 67}}

# %%
# top science students placed

df[(df['degree_t']=='Sci&Tech')&(df['status']=='Placed')].sort_values(by = 'salary',ascending = False).reset_index().head(5)
# Out:
#    index  sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b    hsc_s  degree_p  \
# 0    150    151      M  71.00  Central  58.66  Central  Science     58.00
# 1     77     78      M  64.00   Others  80.00   Others  Science     65.00
# 2    163    164      M  63.00   Others  67.00   Others  Science     64.00
# 3    174    175      M  73.24   Others  50.83   Others  Science     64.27
# 4     53     54      M  80.00   Others  70.00   Others  Science     72.00
#
#    degree_t workex  etest_p specialisation  mba_p  status    salary
# 0  Sci&Tech    Yes     56.0        Mkt&Fin  61.30  Placed  690000.0
# 1  Sci&Tech    Yes     69.0        Mkt&Fin  57.65  Placed  500000.0
# 2  Sci&Tech     No     75.0        Mkt&Fin  66.46  Placed  500000.0
# 3  Sci&Tech    Yes     64.0        Mkt&Fin  66.23  Placed  500000.0
# 4  Sci&Tech     No     87.0         Mkt&HR  71.04  Placed  450000.0

# %%
# top Comm&Mgt students placed

df[(df['degree_t']=='Comm&Mgmt')&(df['status']=='Placed')].sort_values(by = 'salary',ascending = False).reset_index().head(5)
# Out:
#    index  sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0    119    120      M   60.8  Central   68.4  Central  Commerce      64.6
# 1    177    178      F   73.0  Central   97.0   Others  Commerce      79.0
# 2      4      5      M   85.8  Central   73.6  Central  Commerce      73.3
# 3     95     96      M   73.0  Central   78.0   Others  Commerce      65.0
# 4    210    211      M   80.6   Others   82.0   Others  Commerce      77.6
#
#     degree_t workex  etest_p specialisation  mba_p  status    salary
# 0  Comm&Mgmt    Yes    82.66        Mkt&Fin  64.34  Placed  940000.0
# 1  Comm&Mgmt    Yes    89.00        Mkt&Fin  70.81  Placed  650000.0
# 2  Comm&Mgmt     No    96.80        Mkt&Fin  55.50  Placed  425000.0
# 3  Comm&Mgmt    Yes    95.46        Mkt&Fin  62.16  Placed  420000.0
# 4  Comm&Mgmt     No    91.00        Mkt&Fin  74.49  Placed  400000.0

# %%
# max and min salary
# observation : max salary : 9,40,000 and min salary : 2,00,000

df[(df['salary']==max(df['salary'])) | (df['salary']==min(df['salary']))]
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 15      16      F  65.00  Central  75.00  Central  Commerce     69.00
# 44      45      F  77.00   Others  73.00   Others  Commerce     81.00
# 50      51      F  75.20  Central  73.20  Central   Science     68.40
# 107    108      M  82.00   Others  90.00   Others  Commerce     83.00
# 119    120      M  60.80  Central  68.40  Central  Commerce     64.60
# 135    136      F  72.00  Central  56.00   Others   Science     69.00
#
#       degree_t workex  etest_p specialisation  mba_p  status    salary
# 1     Sci&Tech    Yes    86.50        Mkt&Fin  66.28  Placed  200000.0
# 15   Comm&Mgmt    Yes    72.00        Mkt&Fin  64.66  Placed  200000.0
# 44   Comm&Mgmt    Yes    89.00        Mkt&Fin  69.70  Placed  200000.0
# 50   Comm&Mgmt     No    65.00         Mkt&HR  62.98  Placed  200000.0
# 107  Comm&Mgmt     No    80.00         Mkt&HR  73.52  Placed  200000.0
# 119  Comm&Mgmt    Yes    82.66        Mkt&Fin  64.34  Placed  940000.0
# 135  Comm&Mgmt     No    55.60         Mkt&HR  65.63  Placed  200000.0

# %%
# students with salary more than avg salary science dept

df[(df['degree_t']=='Sci&Tech')&(df['salary']>df['salary'].mean())].sort_values(by = 'salary',ascending = False).reset_index()
# Out:
#     index  sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b    hsc_s  degree_p  \
# 0     150    151      M  71.00  Central  58.66  Central  Science     58.00
# 1     174    175      M  73.24   Others  50.83   Others  Science     64.27
# 2      77     78      M  64.00   Others  80.00   Others  Science     65.00
# 3     163    164      M  63.00   Others  67.00   Others  Science     64.00
# 4      53     54      M  80.00   Others  70.00   Others  Science     72.00
# 5      39     40      M  81.00   Others  68.00   Others  Science     64.00
# 6     145    146      M  89.40   Others  65.66   Others  Science     71.25
# 7     128    129      M  80.40  Central  73.40  Central  Science     77.72
# 8      22     23      F  69.80   Others  60.80   Others  Science     72.23
# 9      24     25      M  76.50   Others  97.70   Others  Science     78.86
# 10     70     71      M  82.00   Others  61.00   Others  Science     62.00
# 11    178    179      M  68.00   Others  56.00   Others  Science     68.00
# 12    153    154      M  49.00   Others  59.00   Others  Science     65.00
# 13     37     38      F  79.00  Central  76.00  Central  Science     65.60
# 14     23     24      F  77.40   Others  60.00   Others  Science     64.74
# 15    160    161      M  87.00  Central  74.00  Central  Science     65.00
# 16     83     84      M  84.00   Others  79.00   Others  Science     68.00
# 17     84     85      M  70.00  Central  63.00   Others  Science     70.00
#
#     degree_t workex  etest_p specialisation  mba_p  status    salary
# 0   Sci&Tech    Yes    56.00        Mkt&Fin  61.30  Placed  690000.0
# 1   Sci&Tech    Yes    64.00        Mkt&Fin  66.23  Placed  500000.0
# 2   Sci&Tech    Yes    69.00        Mkt&Fin  57.65  Placed  500000.0
# 3   Sci&Tech     No    75.00        Mkt&Fin  66.46  Placed  500000.0
# 4   Sci&Tech     No    87.00         Mkt&HR  71.04  Placed  450000.0
# 5   Sci&Tech     No    93.00        Mkt&Fin  62.56  Placed  411000.0
# 6   Sci&Tech     No    72.00         Mkt&HR  63.23  Placed  400000.0
# 7   Sci&Tech    Yes    81.20         Mkt&HR  76.26  Placed  400000.0
# 8   Sci&Tech     No    55.53         Mkt&HR  68.81  Placed  360000.0
# 9   Sci&Tech     No    97.40        Mkt&Fin  74.01  Placed  360000.0
# 10  Sci&Tech     No    89.00        Mkt&Fin  65.45  Placed  360000.0
# 11  Sci&Tech     No    73.00         Mkt&HR  68.07  Placed  350000.0
# 12  Sci&Tech    Yes    86.00        Mkt&Fin  62.48  Placed  340000.0
# 13  Sci&Tech     No    58.00         Mkt&HR  55.47  Placed  320000.0
# 14  Sci&Tech    Yes    92.00        Mkt&Fin  63.62  Placed  300000.0
# 15  Sci&Tech    Yes    75.00         Mkt&HR  72.29  Placed  300000.0
# 16  Sci&Tech    Yes    84.00        Mkt&Fin  66.69  Placed  300000.0
# 17  Sci&Tech    Yes    55.00        Mkt&Fin  62.00  Placed  300000.0

# %%
# students with salary more than avg salary Comm&Mgmt dept

df[(df['degree_t']=='Comm&Mgmt')&(df['salary']>df['salary'].mean())].sort_values(by = 'salary',ascending = False).reset_index()
# Out:
#     index  sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0     119    120      M  60.80  Central  68.40  Central  Commerce     64.60
# 1     177    178      F  73.00  Central  97.00   Others  Commerce     79.00
# 2       4      5      M  85.80  Central  73.60  Central  Commerce     73.30
# 3      95     96      M  73.00  Central  78.00   Others  Commerce     65.00
# 4      85     86      F  83.84   Others  89.83   Others  Commerce     77.20
# 5     210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 6      21     22      F  79.00   Others  76.00   Others  Commerce     85.00
# 7     101    102      M  63.00  Central  72.00  Central  Commerce     68.00
# 8     104    105      M  69.00  Central  63.00   Others   Science     65.00
# 9      57     58      M  68.00  Central  76.00  Central  Commerce     74.00
# 10    125    126      F  84.00  Central  73.00  Central  Commerce     73.00
# 11     28     29      M  76.76   Others  76.50   Others  Commerce     67.50
# 12     74     75      M  56.60  Central  64.80  Central  Commerce     70.20
# 13    132    133      M  67.00   Others  68.00   Others  Commerce     64.00
# 14    207    208      M  83.33  Central  78.00   Others  Commerce     61.00
# 15    200    201      M  69.00   Others  60.00   Others  Commerce     65.00
# 16     35     36      F  69.00  Central  78.00  Central  Commerce     72.00
# 17    172    173      M  73.00   Others  58.00   Others  Commerce     56.00
# 18    157    158      M  66.50  Central  62.50  Central  Commerce     60.90
# 19    147    148      M  70.00  Central  74.00  Central  Commerce     65.00
# 20    143    144      M  77.67   Others  64.89   Others  Commerce     70.67
# 21     81     82      M  81.70   Others  63.00   Others   Science     67.00
# 22     43     44      M  87.00   Others  87.00   Others  Commerce     68.00
# 23    116    117      M  68.20  Central  72.80  Central  Commerce     66.60
# 24    108    109      M  61.00  Central  82.00  Central  Commerce     69.00
# 25     16     17      M  63.00  Central  66.20  Central  Commerce     65.60
# 26    102    103      F  77.00   Others  61.00   Others  Commerce     68.00
# 27     96     97      F  76.00  Central  70.00  Central   Science     76.00
# 28     61     62      M  84.20  Central  73.40  Central  Commerce     66.89
# 29     90     91      F  85.00   Others  90.00   Others  Commerce     82.00
# 30    212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 31    171    172      M  80.00   Others  80.00   Others  Commerce     72.00
#
#      degree_t workex  etest_p specialisation  mba_p  status    salary
# 0   Comm&Mgmt    Yes    82.66        Mkt&Fin  64.34  Placed  940000.0
# 1   Comm&Mgmt    Yes    89.00        Mkt&Fin  70.81  Placed  650000.0
# 2   Comm&Mgmt     No    96.80        Mkt&Fin  55.50  Placed  425000.0
# 3   Comm&Mgmt    Yes    95.46        Mkt&Fin  62.16  Placed  420000.0
# 4   Comm&Mgmt    Yes    78.74        Mkt&Fin  76.18  Placed  400000.0
# 5   Comm&Mgmt     No    91.00        Mkt&Fin  74.49  Placed  400000.0
# 6   Comm&Mgmt     No    95.00        Mkt&Fin  69.06  Placed  393000.0
# 7   Comm&Mgmt     No    78.00         Mkt&HR  60.44  Placed  380000.0
# 8   Comm&Mgmt    Yes    55.00         Mkt&HR  58.23  Placed  360000.0
# 9   Comm&Mgmt     No    80.00        Mkt&Fin  63.59  Placed  360000.0
# 10  Comm&Mgmt     No    75.00        Mkt&Fin  73.33  Placed  350000.0
# 11  Comm&Mgmt    Yes    73.35        Mkt&Fin  64.15  Placed  350000.0
# 12  Comm&Mgmt     No    84.27        Mkt&Fin  67.20  Placed  336000.0
# 13  Comm&Mgmt    Yes    74.40         Mkt&HR  53.49  Placed  300000.0
# 14  Comm&Mgmt    Yes    88.56        Mkt&Fin  71.55  Placed  300000.0
# 15  Comm&Mgmt     No    87.55        Mkt&Fin  52.81  Placed  300000.0
# 16  Comm&Mgmt     No    71.00         Mkt&HR  62.74  Placed  300000.0
# 17  Comm&Mgmt     No    84.00         Mkt&HR  52.64  Placed  300000.0
# 18  Comm&Mgmt     No    93.40        Mkt&Fin  55.03  Placed  300000.0
# 19  Comm&Mgmt     No    83.00        Mkt&Fin  62.28  Placed  300000.0
# 20  Comm&Mgmt     No    89.00        Mkt&Fin  60.39  Placed  300000.0
# 21  Comm&Mgmt    Yes    86.00        Mkt&Fin  70.20  Placed  300000.0
# 22  Comm&Mgmt     No    95.00         Mkt&HR  62.90  Placed  300000.0
# 23  Comm&Mgmt    Yes    96.00        Mkt&Fin  70.85  Placed  300000.0
# 24  Comm&Mgmt     No    84.00        Mkt&Fin  58.31  Placed  300000.0
# 25  Comm&Mgmt    Yes    60.00        Mkt&Fin  62.54  Placed  300000.0
# 26  Comm&Mgmt    Yes    57.50        Mkt&Fin  61.31  Placed  300000.0
# 27  Comm&Mgmt    Yes    66.00        Mkt&Fin  64.44  Placed  300000.0
# 28  Comm&Mgmt     No    61.60        Mkt&Fin  62.48  Placed  300000.0
# 29  Comm&Mgmt     No    92.00        Mkt&Fin  68.03  Placed  300000.0
# 30  Comm&Mgmt    Yes    59.00        Mkt&Fin  69.72  Placed  295000.0
# 31  Comm&Mgmt    Yes    63.79        Mkt&Fin  66.04  Placed  290000.0

# %%
# maximum students placed are from comm&mgt

df.groupby(['degree_t'])['status'].count().plot(kind = 'bar',color = 'magenta')
# Out:
# <Axes: xlabel='degree_t'>

# %%
# Marketing and Finance specialisation are placed more

df.groupby(['specialisation'])['status'].count().plot(kind = 'bar',color = 'magenta')
# Out:
# <Axes: xlabel='specialisation'>

# %%
# females placed 35% and males 65%

df.groupby(['gender'])['status'].count().plot(kind = 'pie',autopct='%1.0f%%')
# Out:
# <Axes: ylabel='status'>

# %%
df.groupby(['hsc_s'])['status'].count().plot(kind = 'pie',autopct='%1.0f%%',figsize=(15,7))
# Out:
# <Axes: ylabel='status'>

# %%
df.head()
# Out:
#    sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1      2      M  79.33  Central  78.33   Others   Science     77.48
# 2      3      M  65.00  Central  68.00  Central      Arts     64.00
# 3      4      M  56.00  Central  52.00  Central   Science     52.00
# 4      5      M  85.80  Central  73.60  Central  Commerce     73.30
#
#     degree_t workex  etest_p specialisation  mba_p      status         salary
# 0   Sci&Tech     No     55.0         Mkt&HR  58.80      Placed  270000.000000
# 1   Sci&Tech    Yes     86.5        Mkt&Fin  66.28      Placed  200000.000000
# 2  Comm&Mgmt     No     75.0        Mkt&Fin  57.80      Placed  250000.000000
# 3   Sci&Tech     No     66.0         Mkt&HR  59.43  Not Placed  288655.405405
# 4  Comm&Mgmt     No     96.8        Mkt&Fin  55.50      Placed  425000.000000

# %%
getfinaldict
# Out:
# {'gender': {'M': 139, 'F': 76},
#  'ssc_b': {'Central': 116, 'Others': 99},
#  'hsc_b': {'Others': 131, 'Central': 84},
#  'hsc_s': {'Commerce': 113, 'Science': 91, 'Arts': 11},
#  'degree_t': {'Comm&Mgmt': 145, 'Sci&Tech': 59, 'Others': 11},
#  'workex': {'No': 141, 'Yes': 74},
#  'specialisation': {'Mkt&Fin': 120, 'Mkt&HR': 95},
#  'status': {'Placed': 148, 'Not Placed': 67}}

# %%
len(getfinaldict['status']),len(getfinaldict['degree_t'])
# Out:
# (2, 3)

# %%
boolcols = [key for key,value in getfinaldict.items() if len(getfinaldict[key])==2]
tripcols = [key for key in list(getfinaldict.keys()) if key not in boolcols]

print(boolcols,tripcols)
# Out:
# ['gender', 'ssc_b', 'hsc_b', 'workex', 'specialisation', 'status'] ['hsc_s', 'degree_t']

# %% [markdown]
# ## Label Encoding process

# %%
def labelencode(le,col):

    df[col] = le.fit_transform(df[col])


getmappings = {}
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for col in list(getfinaldict.keys()):
    labelencode(le,col)
    getmappings[col] = dict(zip(le.classes_,le.transform(le.classes_)))


df.head()
# Out:
#    sl_no  gender  ssc_p  ssc_b  hsc_p  hsc_b  hsc_s  degree_p  degree_t  \
# 0      1       1  67.00      1  91.00      1      1     58.00         2
# 1      2       1  79.33      0  78.33      1      2     77.48         2
# 2      3       1  65.00      0  68.00      0      0     64.00         0
# 3      4       1  56.00      0  52.00      0      2     52.00         2
# 4      5       1  85.80      0  73.60      0      1     73.30         0
#
#    workex  etest_p  specialisation  mba_p  status         salary
# 0       0     55.0               1  58.80       1  270000.000000
# 1       1     86.5               0  66.28       1  200000.000000
# 2       0     75.0               0  57.80       1  250000.000000
# 3       0     66.0               1  59.43       0  288655.405405
# 4       0     96.8               0  55.50       1  425000.000000

# %%
# this was the internal mapping structure followed by label encoder for mapping

getmappings
# Out:
# {'gender': {'F': 0, 'M': 1},
#  'ssc_b': {'Central': 0, 'Others': 1},
#  'hsc_b': {'Central': 0, 'Others': 1},
#  'hsc_s': {'Arts': 0, 'Commerce': 1, 'Science': 2},
#  'degree_t': {'Comm&Mgmt': 0, 'Others': 1, 'Sci&Tech': 2},
#  'workex': {'No': 0, 'Yes': 1},
#  'specialisation': {'Mkt&Fin': 0, 'Mkt&HR': 1},
#  'status': {'Not Placed': 0, 'Placed': 1}}

# %%
# removing unwated columns

df = df.drop(['sl_no'],axis=1)
df.head(2)
# Out:
#    gender  ssc_p  ssc_b  hsc_p  hsc_b  hsc_s  degree_p  degree_t  workex  \
# 0       1  67.00      1  91.00      1      1     58.00         2       0
# 1       1  79.33      0  78.33      1      2     77.48         2       1
#
#    etest_p  specialisation  mba_p  status    salary
# 0     55.0               1  58.80       1  270000.0
# 1     86.5               0  66.28       1  200000.0

# %% [markdown]
# ## Numerical Columns EDA

# %%
numvars[1:]
# Out:
# ['ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary']

# %%
import scipy.stats as stats

def getplots(df,col):

    plt.figure(figsize=(15,7))
    plt.subplot(1,3,1)
    plt.hist(df[col],color='magenta')

    plt.subplot(1,3,2)
    stats.probplot(df[col],dist='norm',plot=plt)

    plt.subplot(1,3,3)
    sn.boxplot(df[col],color='magenta')

    plt.show()


for col in numvars[1:]:
    print(f'Distribution plots for col : {col} are shown ↓')
    getplots(df,col)
    print('='*10)
# Out:
# Distribution plots for col : ssc_p are shown ↓
# ==========
# Distribution plots for col : hsc_p are shown ↓
# ==========
# Distribution plots for col : degree_p are shown ↓
# ==========
# Distribution plots for col : etest_p are shown ↓
# ==========
# Distribution plots for col : mba_p are shown ↓
# ==========
# Distribution plots for col : salary are shown ↓
# ==========

# %%
# checking for tightly correlated features

plt.figure(figsize=(15,7))
sn.heatmap(df.corr(),annot=True,cmap='plasma')
# Out:
# <Axes: >

# %%
data = df.copy()
test = data['status']
train = data.drop(['status','salary'],axis = 1)
train.head(2)
# Out:
#    gender  ssc_p  ssc_b  hsc_p  hsc_b  hsc_s  degree_p  degree_t  workex  \
# 0       1  67.00      1  91.00      1      1     58.00         2       0
# 1       1  79.33      0  78.33      1      2     77.48         2       1
#
#    etest_p  specialisation  mba_p
# 0     55.0               1  58.80
# 1     86.5               0  66.28

# %%
## extratrees classifier

from sklearn.ensemble import ExtraTreesClassifier
ec = ExtraTreesClassifier()
ec.fit(train,test)
# Out:
# ExtraTreesClassifier()

# %%
featbar = pd.Series(ec.feature_importances_,index=train.columns)
featbar.nlargest(7).plot(kind = 'barh')
# Out:
# <Axes: >

# %%
featbar.nlargest(7).plot(kind='pie',autopct='%1.0f%%',figsize = (15,7))
# Out:
# <Axes: >

# %%
# mutual classif

from sklearn.feature_selection import mutual_info_classif
mc = mutual_info_classif(train,test)
ax = pd.Series(mc,index=train.columns)
ax.nlargest(7).plot(kind = 'barh')
# Out:
# <Axes: >

# %%
pd.Series(mc,index=train.columns).plot(kind = 'pie',autopct='%1.0f%%',figsize = (15,7))
# Out:
# <Axes: >

# %%
'''
Selecting the top 10 contributing features in both cases
and then we will do the intersection of both the results
so that we will get atleast top 5 most contributing features!

'''

featcol = list(featbar.nlargest(10).index)
mutclasif = list(ax.nlargest(10).index)
commoncols = list(set(featcol).intersection(set(mutclasif)))
print(commoncols)
# Out:
# ['ssc_p', 'ssc_b', 'hsc_p', 'gender', 'degree_p', 'degree_t', 'specialisation', 'workex', 'mba_p']

# %%
# selecting the common cols and will do training on these cols!
# these cols were selected as a nlargest result of 2 feature selection techniques!

train = df[commoncols]
train.head()
# Out:
#    ssc_p  ssc_b  hsc_p  gender  degree_p  degree_t  specialisation  workex  \
# 0  67.00      1  91.00       1     58.00         2               1       0
# 1  79.33      0  78.33       1     77.48         2               0       1
# 2  65.00      0  68.00       1     64.00         0               0       0
# 3  56.00      0  52.00       1     52.00         2               1       0
# 4  85.80      0  73.60       1     73.30         0               0       0
#
#    mba_p
# 0  58.80
# 1  66.28
# 2  57.80
# 3  59.43
# 4  55.50

# %%
'''
From the above DF we notice that gender,specialisation,degree_t,workex are the
categorical columns and they make sense,for any placement drive
students are first filtered on basis of their boards,sem scores which in this case are {mba_p,ssc_p,degree_p,hsc_p}
and then workexperience also matters a lot!,then specialisation as well,gender is also important
because now-a-days few companies focus on women empowerment,so yes,all the features make perfect sense!

'''
getmappings
# Out:
# {'gender': {'F': 0, 'M': 1},
#  'ssc_b': {'Central': 0, 'Others': 1},
#  'hsc_b': {'Central': 0, 'Others': 1},
#  'hsc_s': {'Arts': 0, 'Commerce': 1, 'Science': 2},
#  'degree_t': {'Comm&Mgmt': 0, 'Others': 1, 'Sci&Tech': 2},
#  'workex': {'No': 0, 'Yes': 1},
#  'specialisation': {'Mkt&Fin': 0, 'Mkt&HR': 1},
#  'status': {'Not Placed': 0, 'Placed': 1}}

# %%
# renaming the cols

train = train[['gender','specialisation','degree_t','workex','ssc_p','hsc_p','degree_p','mba_p']]
train.columns = ['Gender','Specialisation','Techinal Degree','Work Experience','SSC_p','High School_p','Degree_p','MBA_p']
train.head()
# Out:
#    Gender  Specialisation  Techinal Degree  Work Experience  SSC_p  \
# 0       1               1                2                0  67.00
# 1       1               0                2                1  79.33
# 2       1               0                0                0  65.00
# 3       1               1                2                0  56.00
# 4       1               0                0                0  85.80
#
#    High School_p  Degree_p  MBA_p
# 0          91.00     58.00  58.80
# 1          78.33     77.48  66.28
# 2          68.00     64.00  57.80
# 3          52.00     52.00  59.43
# 4          73.60     73.30  55.50

# %%
train['Techinal Degree'].value_counts()
# Out:
# Techinal Degree
# 0    145
# 2     59
# 1     11
# Name: count, dtype: int64

# %% [markdown]
# ### Model Building

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn import tree
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split,RandomizedSearchCV,cross_val_score
from sklearn import metrics

# %%
X_train, X_test, y_train, y_test = train_test_split(train,test,test_size=0.2)
X_train.shape,X_test.shape
# Out:
# ((172, 8), (43, 8))

# %%
dc = DecisionTreeClassifier()
dc.fit(X_train,y_train)
plt.figure(figsize=(16,9))
tree.plot_tree(dc,filled=True,class_names=['Not_placed','Placed'],feature_names=train.columns)
# Out:
# [Text(0.287109375, 0.9375, 'SSC_p <= 56.44\ngini = 0.431\nsamples = 172\nvalue = [54, 118]\nclass = Placed'),
#  Text(0.0625, 0.8125, 'High School_p <= 60.665\ngini = 0.18\nsamples = 30\nvalue = [27, 3]\nclass = Not_placed'),
#  Text(0.1748046875, 0.875, 'True  '),
#  Text(0.03125, 0.6875, 'gini = 0.0\nsamples = 20\nvalue = [20, 0]\nclass = Not_placed'),
#  Text(0.09375, 0.6875, 'MBA_p <= 58.37\ngini = 0.42\nsamples = 10\nvalue = [7, 3]\nclass = Not_placed'),
#  Text(0.0625, 0.5625, 'Specialisation <= 0.5\ngini = 0.48\nsamples = 5\nvalue = [2, 3]\nclass = Placed'),
#  Text(0.03125, 0.4375, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Placed'),
#  Text(0.09375, 0.4375, 'High School_p <= 62.08\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Not_placed'),
#  Text(0.0625, 0.3125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Placed'),
#  Text(0.125, 0.3125, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Not_placed'),
#  Text(0.125, 0.5625, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = Not_placed'),
#  Text(0.51171875, 0.8125, 'Degree_p <= 64.24\ngini = 0.308\nsamples = 142\nvalue = [27, 115]\nclass = Placed'),
#  Text(0.3994140625, 0.875, '  False'),
#  Text(0.34375, 0.6875, 'SSC_p <= 66.25\ngini = 0.5\nsamples = 39\nvalue = [19, 20]\nclass = Placed'),
#  Text(0.28125, 0.5625, 'Work Experience <= 0.5\ngini = 0.435\nsamples = 25\nvalue = [17, 8]\nclass = Not_placed'),
#  Text(0.25, 0.4375, 'SSC_p <= 59.3\ngini = 0.308\nsamples = 21\nvalue = [17, 4]\nclass = Not_placed'),
#  Text(0.1875, 0.3125, 'High School_p <= 63.0\ngini = 0.5\nsamples = 6\nvalue = [3, 3]\nclass = Not_placed'),
#  Text(0.15625, 0.1875, 'MBA_p <= 58.355\ngini = 0.375\nsamples = 4\nvalue = [1, 3]\nclass = Placed'),
#  Text(0.125, 0.0625, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Placed'),
#  Text(0.1875, 0.0625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Not_placed'),
#  Text(0.21875, 0.1875, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Not_placed'),
#  Text(0.3125, 0.3125, 'High School_p <= 70.8\ngini = 0.124\nsamples = 15\nvalue = [14, 1]\nclass = Not_placed'),
#  Text(0.28125, 0.1875, 'gini = 0.0\nsamples = 14\nvalue = [14, 0]\nclass = Not_placed'),
#  Text(0.34375, 0.1875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Placed'),
#  Text(0.3125, 0.4375, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = Placed'),
#  Text(0.40625, 0.5625, 'MBA_p <= 68.83\ngini = 0.245\nsamples = 14\nvalue = [2, 12]\nclass = Placed'),
#  Text(0.375, 0.4375, 'gini = 0.0\nsamples = 11\nvalue = [0, 11]\nclass = Placed'),
#  Text(0.4375, 0.4375, 'Work Experience <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Not_placed'),
#  Text(0.40625, 0.3125, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Not_placed'),
#  Text(0.46875, 0.3125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Placed'),
#  Text(0.6796875, 0.6875, 'Techinal Degree <= 0.5\ngini = 0.143\nsamples = 103\nvalue = [8.0, 95.0]\nclass = Placed'),
#  Text(0.53125, 0.5625, 'MBA_p <= 71.24\ngini = 0.028\nsamples = 70\nvalue = [1, 69]\nclass = Placed'),
#  Text(0.5, 0.4375, 'gini = 0.0\nsamples = 64\nvalue = [0, 64]\nclass = Placed'),
#  Text(0.5625, 0.4375, 'Degree_p <= 67.8\ngini = 0.278\nsamples = 6\nvalue = [1, 5]\nclass = Placed'),
#  Text(0.53125, 0.3125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Not_placed'),
#  Text(0.59375, 0.3125, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = Placed'),
#  Text(0.828125, 0.5625, 'SSC_p <= 69.85\ngini = 0.334\nsamples = 33\nvalue = [7, 26]\nclass = Placed'),
#  Text(0.71875, 0.4375, 'Degree_p <= 67.5\ngini = 0.48\nsamples = 10\nvalue = [6, 4]\nclass = Not_placed'),
#  Text(0.65625, 0.3125, 'Degree_p <= 64.665\ngini = 0.278\nsamples = 6\nvalue = [5, 1]\nclass = Not_placed'),
#  Text(0.625, 0.1875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Placed'),
#  Text(0.6875, 0.1875, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = Not_placed'),
#  Text(0.78125, 0.3125, 'High School_p <= 51.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]\nclass = Placed'),
#  Text(0.75, 0.1875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Not_placed'),
#  Text(0.8125, 0.1875, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Placed'),
#  Text(0.9375, 0.4375, 'SSC_p <= 76.25\ngini = 0.083\nsamples = 23\nvalue = [1, 22]\nclass = Placed'),
#  Text(0.90625, 0.3125, 'Gender <= 0.5\ngini = 0.278\nsamples = 6\nvalue = [1, 5]\nclass = Placed'),
#  Text(0.875, 0.1875, 'High School_p <= 62.25\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Not_placed'),
#  Text(0.84375, 0.0625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Placed'),
#  Text(0.90625, 0.0625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Not_placed'),
#  Text(0.9375, 0.1875, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = Placed'),
#  Text(0.96875, 0.3125, 'gini = 0.0\nsamples = 17\nvalue = [0, 17]\nclass = Placed')]

# %%
costpath = dc.cost_complexity_pruning_path(train,test)
ccp_alpha,impurities = costpath.ccp_alphas,costpath.impurities

# %%
modellist = []
for alpha in ccp_alpha:
    dc = DecisionTreeClassifier(ccp_alpha=alpha)
    dc.fit(X_train,y_train)
    modellist.append(dc)

# %%
train_score = [clf.score(X_train,y_train) for clf in modellist]
test_score = [clf.score(X_test,y_test) for clf in modellist]

plt.xlabel('alpha_value')
plt.ylabel('accuracy')
plt.plot(ccp_alpha,train_score,label = 'train_score',marker = '+',color = 'magenta')
plt.plot(ccp_alpha,test_score,label = 'test_score',marker = '*',color = 'red')
plt.legend()
plt.show()

# %%
dc = DecisionTreeClassifier(ccp_alpha=0.0195)
dc.fit(X_train,y_train)
plt.figure(figsize=(15,7))
tree.plot_tree(dc,filled=True,class_names=['Not_placed','Placed'],feature_names=train.columns)
# Out:
# [Text(0.5, 0.9, 'SSC_p <= 56.44\ngini = 0.431\nsamples = 172\nvalue = [54, 118]\nclass = Placed'),
#  Text(0.3333333333333333, 0.7, 'gini = 0.18\nsamples = 30\nvalue = [27, 3]\nclass = Not_placed'),
#  Text(0.41666666666666663, 0.8, 'True  '),
#  Text(0.6666666666666666, 0.7, 'Degree_p <= 64.24\ngini = 0.308\nsamples = 142\nvalue = [27, 115]\nclass = Placed'),
#  Text(0.5833333333333333, 0.8, '  False'),
#  Text(0.5, 0.5, 'SSC_p <= 66.25\ngini = 0.5\nsamples = 39\nvalue = [19, 20]\nclass = Placed'),
#  Text(0.3333333333333333, 0.3, 'Work Experience <= 0.5\ngini = 0.435\nsamples = 25\nvalue = [17, 8]\nclass = Not_placed'),
#  Text(0.16666666666666666, 0.1, 'gini = 0.308\nsamples = 21\nvalue = [17, 4]\nclass = Not_placed'),
#  Text(0.5, 0.1, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = Placed'),
#  Text(0.6666666666666666, 0.3, 'gini = 0.245\nsamples = 14\nvalue = [2, 12]\nclass = Placed'),
#  Text(0.8333333333333334, 0.5, 'gini = 0.143\nsamples = 103\nvalue = [8.0, 95.0]\nclass = Placed')]

# %% [markdown]
# # Hyperparameter Tuning

# %%
params = {
    'RandomForest':{
        'model': RandomForestClassifier(),
        'params':{
            'n_estimators': [int(x) for x in np.linspace(start=1,stop=1200,num=10)],
            'max_depth':[int(x) for x in np.linspace(start=1,stop=30,num=5)],
            'min_samples_split':[2,5,10,12],
            'min_samples_leaf':[2,5,10,12],
            'max_features':['auto','sqrt'],
            'ccp_alpha':[0.0185,0.0190,0.0195,0.0200],
        }
    },

    'logistic':{
        'model':LogisticRegression(),
        'params':{
            'penalty':['l1', 'l2', 'elasticnet'],
            'C':[0.25,0.50,0.75,1.0],
            'tol':[1e-10,1e-5,1e-4,1e-3,0.025,0.25,0.50],
            'solver':['lbfgs','liblinear','saga','newton-cg'],
            'multi_class':['auto', 'ovr', 'multinomial'],
            'max_iter':[int(x) for x in np.linspace(start=1,stop=250,num=10)],
        }
    },
    'D-tree':{
        'model':DecisionTreeClassifier(),
        'params':{
            'criterion':['gini','entropy'],
            'splitter':['best','random'],
            'min_samples_split':[1,2,5,10,12],
            'min_samples_leaf':[1,2,5,10,12],
            'max_features':['auto','sqrt'],
            'ccp_alpha':[0.0185,0.0190,0.0195,0.0200],
        }
    },
    'SVM':{
        'model':SVC(),
        'params':{
            'C':[0.25,0.50,0.75,1.0],
            'tol':[1e-10,1e-5,1e-4,0.025,0.50,0.75],
            'kernel':['linear','poly','sigmoid','rbf'],
            'max_iter':[int(x) for x in np.linspace(start=1,stop=250,num=10)],
        }
    }
}

# %%
scores = []
for model_name,mp in params.items():

    clf = RandomizedSearchCV(mp['model'],param_distributions=mp['params'],cv=5,n_iter=10,n_jobs=-1,scoring='accuracy')
    clf.fit(X_train,y_train)
    scores.append({
        'model_name':model_name,
        'best_score':clf.best_score_,
        'best_estimator':clf.best_estimator_
    })
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:540: FitFailedWarning:
# 10 fits failed out of a total of 50.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 10 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestClassifier must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py:1103: UserWarning: One or more of the test scores are non-finite: [0.79663866 0.78521008        nan 0.86084034 0.75630252 0.86084034
#         nan 0.78453782 0.86084034 0.85495798]
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:540: FitFailedWarning:
# 25 fits failed out of a total of 50.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 1473, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py", line 1194, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py", line 67, in _check_solver
#     raise ValueError(
# ValueError: Solver newton-cg supports only 'l2' or None penalties, got l1 penalty.
#
# --------------------------------------------------------------------------------
# 10 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 1473, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py", line 1204, in fit
#     raise ValueError("l1_ratio must be specified when penalty is elasticnet.")
# ValueError: l1_ratio must be specified when penalty is elasticnet.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 1473, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py", line 1194, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py", line 67, in _check_solver
#     raise ValueError(
# ValueError: Solver newton-cg supports only 'l2' or None penalties, got elasticnet penalty.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 1473, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py", line 1194, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py", line 67, in _check_solver
#     raise ValueError(
# ValueError: Solver lbfgs supports only 'l2' or None penalties, got l1 penalty.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py:1103: UserWarning: One or more of the test scores are non-finite: [0.8605042  0.79630252 0.61529412        nan        nan        nan
#         nan 0.88369748        nan 0.86067227]
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:1237: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, binary problems will be fit as proper binary  logistic regression models (as if multi_class='ovr' were set). Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:540: FitFailedWarning:
# 20 fits failed out of a total of 50.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 15 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of DecisionTreeClassifier must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'min_samples_split' parameter of DecisionTreeClassifier must be an int in the range [2, inf) or a float in the range (0.0, 1.0]. Got 1 instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py:1103: UserWarning: One or more of the test scores are non-finite: [0.78453782 0.73260504 0.78504202        nan 0.77327731        nan
#  0.81445378        nan 0.73294118        nan]
#   warnings.warn(

# %%
scores_df = pd.DataFrame(data = scores,columns = ['model_name','best_score','best_estimator'])
scores_df.head()
# Out:
#      model_name  best_score                                     best_estimator
# 0  RandomForest    0.860840  (DecisionTreeClassifier(ccp_alpha=0.019, max_d...
# 1      logistic    0.883697  LogisticRegression(C=0.25, max_iter=139, multi...
# 2        D-tree    0.814454  DecisionTreeClassifier(ccp_alpha=0.0195, max_f...
# 3           SVM    0.831429                SVC(C=0.5, max_iter=111, tol=0.025)

# %%
scores
# Out:
# [{'model_name': 'RandomForest',
#   'best_score': 0.8608403361344538,
#   'best_estimator': RandomForestClassifier(ccp_alpha=0.019, max_depth=15, min_samples_leaf=5,
#                          n_estimators=800)},
#  {'model_name': 'logistic',
#   'best_score': 0.8836974789915967,
#   'best_estimator': LogisticRegression(C=0.25, max_iter=139, multi_class='multinomial', tol=1e-05)},
#  {'model_name': 'D-tree',
#   'best_score': 0.814453781512605,
#   'best_estimator': DecisionTreeClassifier(ccp_alpha=0.0195, max_features='sqrt',
#                          min_samples_split=10)},
#  {'model_name': 'SVM',
#   'best_score': 0.8314285714285713,
#   'best_estimator': SVC(C=0.5, max_iter=111, tol=0.025)}]

# %%
# random forest model


rf = RandomForestClassifier(ccp_alpha=0.02, max_depth=30, max_features='sqrt',
                         min_samples_leaf=2, min_samples_split=12,
                         n_estimators=267)
rf.fit(X_train,y_train)
y_pred = rf.predict(X_test)
print(metrics.accuracy_score(y_test,y_pred))
# Out:
# 0.8604651162790697

# %%
# logistic regression

lr = LogisticRegression(C=0.25, max_iter=111, multi_class='ovr', solver='newton-cg',
                     tol=1e-05)

lr.fit(X_train,y_train)
y_pred = lr.predict(X_test)
print(metrics.accuracy_score(y_test,y_pred))
# Out:
# 0.7906976744186046
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:1256: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. Use OneVsRestClassifier(LogisticRegression(..)) instead. Leave it to its default value to avoid this warning.
#   warnings.warn(

# %%
# decision tree

dc = DecisionTreeClassifier(ccp_alpha=0.019, criterion='entropy',
                         max_features=None, min_samples_leaf=5, # Changed max_features to None
                         min_samples_split=5, splitter='random')
dc.fit(X_train,y_train)
y_pred = dc.predict(X_test)
print(metrics.accuracy_score(y_test,y_pred))
# Out:
# 0.6744186046511628

# %%
print(metrics.classification_report(y_test,rf.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.62      0.73        13
#            1       0.85      0.97      0.91        30
#
#     accuracy                           0.86        43
#    macro avg       0.87      0.79      0.82        43
# weighted avg       0.86      0.86      0.85        43

# %%
cn = metrics.confusion_matrix(y_test,rf.predict(X_test))
sn.heatmap(cn,annot=True,cmap='plasma')
# Out:
# <Axes: >

# %% [markdown]
# # Model Testing

# %%
traindata = np.array(train)
predicted = []
for i in range(len(traindata)):
    predicted.append(rf.predict([traindata[i]]))

predicted
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# [array([1]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([0])]

# %%
resultdf = train.copy()
resultdf['Actual'] = np.array(test)
resultdf['Predicted'] = np.array(predicted)
resultdf.head()
# Out:
#    Gender  Specialisation  Techinal Degree  Work Experience  SSC_p  \
# 0       1               1                2                0  67.00
# 1       1               0                2                1  79.33
# 2       1               0                0                0  65.00
# 3       1               1                2                0  56.00
# 4       1               0                0                0  85.80
#
#    High School_p  Degree_p  MBA_p  Actual  Predicted
# 0          91.00     58.00  58.80       1          1
# 1          78.33     77.48  66.28       1          1
# 2          68.00     64.00  57.80       1          1
# 3          52.00     52.00  59.43       0          0
# 4          73.60     73.30  55.50       1          1

# %%
resultdf['Actual'].value_counts()
# Out:
# Actual
# 1    148
# 0     67
# Name: count, dtype: int64

# %%
resultdf['Predicted'].value_counts()
# Out:
# Predicted
# 1    161
# 0     54
# Name: count, dtype: int64

# %%
getmappings
# Out:
# {'gender': {'F': 0, 'M': 1},
#  'ssc_b': {'Central': 0, 'Others': 1},
#  'hsc_b': {'Central': 0, 'Others': 1},
#  'hsc_s': {'Arts': 0, 'Commerce': 1, 'Science': 2},
#  'degree_t': {'Comm&Mgmt': 0, 'Others': 1, 'Sci&Tech': 2},
#  'workex': {'No': 0, 'Yes': 1},
#  'specialisation': {'Mkt&Fin': 0, 'Mkt&HR': 1},
#  'status': {'Not Placed': 0, 'Placed': 1}}

# %% [markdown]
# ### Predicted Probability

# %%
traindata = np.array(train)
predicted = []
for i in range(len(traindata)):
    predicted.append(rf.predict_proba([traindata[i]]))

predicted
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# [array([[0.35968432, 0.64031568]]),
#  array([[0.06280542, 0.93719458]]),
#  array([[0.27928931, 0.72071069]]),
#  array([[0.89503713, 0.10496287]]),
#  array([[0.06390853, 0.93609147]]),
#  array([[0.66954616, 0.33045384]]),
#  array([[0.73873467, 0.26126533]]),
#  array([[0.07858107, 0.92141893]]),
#  array([[0.06257881, 0.93742119]]),
#  array([[0.55025473, 0.44974527]]),
#  array([[0.4382444, 0.5617556]]),
#  array([[0.06712278, 0.93287722]]),
#  array([[0.83713961, 0.16286039]]),
#  array([[0.23812499, 0.76187501]]),
#  array([[0.74896363, 0.25103637]]),
#  array([[0.06670699, 0.93329301]]),
#  array([[0.15041628, 0.84958372]]),
#  array([[0.72213317, 0.27786683]]),
#  array([[0.60315861, 0.39684139]]),
#  array([[0.14680067, 0.85319933]]),
#  array([[0.15910125, 0.84089875]]),
#  array([[0.07105281, 0.92894719]]),
#  array([[0.19591995, 0.80408005]]),
#  array([[0.15504169, 0.84495831]]),
#  array([[0.07613266, 0.92386734]]),
#  array([[0.77889478, 0.22110522]]),
#  array([[0.06099321, 0.93900679]]),
#  array([[0.14513721, 0.85486279]]),
#  array([[0.06042345, 0.93957655]]),
#  array([[0.53608751, 0.46391249]]),
#  array([[0.1180906, 0.8819094]]),
#  array([[0.58224583, 0.41775417]]),
#  array([[0.17079753, 0.82920247]]),
#  array([[0.0909856, 0.9090144]]),
#  array([[0.8497443, 0.1502557]]),
#  array([[0.07911665, 0.92088335]]),
#  array([[0.88045889, 0.11954111]]),
#  array([[0.16085938, 0.83914062]]),
#  array([[0.15682636, 0.84317364]]),
#  array([[0.25432373, 0.74567627]]),
#  array([[0.0686858, 0.9313142]]),
#  array([[0.21050713, 0.78949287]]),
#  array([[0.82390622, 0.17609378]]),
#  array([[0.06897567, 0.93102433]]),
#  array([[0.06239448, 0.93760552]]),
#  array([[0.15772652, 0.84227348]]),
#  array([[0.27657041, 0.72342959]]),
#  array([[0.20647136, 0.79352864]]),
#  array([[0.1537209, 0.8462791]]),
#  array([[0.8630013, 0.1369987]]),
#  array([[0.0728224, 0.9271776]]),
#  array([[0.73206538, 0.26793462]]),
#  array([[0.91113342, 0.08886658]]),
#  array([[0.12143234, 0.87856766]]),
#  array([[0.11392766, 0.88607234]]),
#  array([[0.35084097, 0.64915903]]),
#  array([[0.38564304, 0.61435696]]),
#  array([[0.0660853, 0.9339147]]),
#  array([[0.07470561, 0.92529439]]),
#  array([[0.42167793, 0.57832207]]),
#  array([[0.06367218, 0.93632782]]),
#  array([[0.06491362, 0.93508638]]),
#  array([[0.09986553, 0.90013447]]),
#  array([[0.57557911, 0.42442089]]),
#  array([[0.06618521, 0.93381479]]),
#  array([[0.86278367, 0.13721633]]),
#  array([[0.07186651, 0.92813349]]),
#  array([[0.06433094, 0.93566906]]),
#  array([[0.47977432, 0.52022568]]),
#  array([[0.06745279, 0.93254721]]),
#  array([[0.26234768, 0.73765232]]),
#  array([[0.07285253, 0.92714747]]),
#  array([[0.0819674, 0.9180326]]),
#  array([[0.06932476, 0.93067524]]),
#  array([[0.26349544, 0.73650456]]),
#  array([[0.27136075, 0.72863925]]),
#  array([[0.1001121, 0.8998879]]),
#  array([[0.14476734, 0.85523266]]),
#  array([[0.14135336, 0.85864664]]),
#  array([[0.22840126, 0.77159874]]),
#  array([[0.09532679, 0.90467321]]),
#  array([[0.08039554, 0.91960446]]),
#  array([[0.14522011, 0.85477989]]),
#  array([[0.06393461, 0.93606539]]),
#  array([[0.09184763, 0.90815237]]),
#  array([[0.0712329, 0.9287671]]),
#  array([[0.38456032, 0.61543968]]),
#  array([[0.86028649, 0.13971351]]),
#  array([[0.14321453, 0.85678547]]),
#  array([[0.07445666, 0.92554334]]),
#  array([[0.06809144, 0.93190856]]),
#  array([[0.85879231, 0.14120769]]),
#  array([[0.23786051, 0.76213949]]),
#  array([[0.64713261, 0.35286739]]),
#  array([[0.3890634, 0.6109366]]),
#  array([[0.09075177, 0.90924823]]),
#  array([[0.07442799, 0.92557201]]),
#  array([[0.41100448, 0.58899552]]),
#  array([[0.15177383, 0.84822617]]),
#  array([[0.64417356, 0.35582644]]),
#  array([[0.78214062, 0.21785938]]),
#  array([[0.12233175, 0.87766825]]),
#  array([[0.07541134, 0.92458866]]),
#  array([[0.07316256, 0.92683744]]),
#  array([[0.14268623, 0.85731377]]),
#  array([[0.51489842, 0.48510158]]),
#  array([[0.79794805, 0.20205195]]),
#  array([[0.07723, 0.92277]]),
#  array([[0.13051353, 0.86948647]]),
#  array([[0.54885546, 0.45114454]]),
#  array([[0.15731652, 0.84268348]]),
#  array([[0.89847452, 0.10152548]]),
#  array([[0.45297231, 0.54702769]]),
#  array([[0.06640839, 0.93359161]]),
#  array([[0.09932959, 0.90067041]]),
#  array([[0.0955443, 0.9044557]]),
#  array([[0.06825112, 0.93174888]]),
#  array([[0.07235322, 0.92764678]]),
#  array([[0.07655506, 0.92344494]]),
#  array([[0.22190243, 0.77809757]]),
#  array([[0.85967595, 0.14032405]]),
#  array([[0.16522667, 0.83477333]]),
#  array([[0.09882589, 0.90117411]]),
#  array([[0.0876595, 0.9123405]]),
#  array([[0.19417175, 0.80582825]]),
#  array([[0.07542661, 0.92457339]]),
#  array([[0.09008741, 0.90991259]]),
#  array([[0.1012733, 0.8987267]]),
#  array([[0.07971141, 0.92028859]]),
#  array([[0.06446425, 0.93553575]]),
#  array([[0.55500193, 0.44499807]]),
#  array([[0.28858476, 0.71141524]]),
#  array([[0.18595402, 0.81404598]]),
#  array([[0.07432458, 0.92567542]]),
#  array([[0.06536821, 0.93463179]]),
#  array([[0.22512255, 0.77487745]]),
#  array([[0.80014561, 0.19985439]]),
#  array([[0.10240264, 0.89759736]]),
#  array([[0.09763977, 0.90236023]]),
#  array([[0.14027448, 0.85972552]]),
#  array([[0.06773387, 0.93226613]]),
#  array([[0.47081342, 0.52918658]]),
#  array([[0.07494099, 0.92505901]]),
#  array([[0.0731308, 0.9268692]]),
#  array([[0.90102575, 0.09897425]]),
#  array([[0.10790588, 0.89209412]]),
#  array([[0.16051156, 0.83948844]]),
#  array([[0.16610723, 0.83389277]]),
#  array([[0.23432186, 0.76567814]]),
#  array([[0.73992577, 0.26007423]]),
#  array([[0.22200921, 0.77799079]]),
#  array([[0.09757298, 0.90242702]]),
#  array([[0.11305022, 0.88694978]]),
#  array([[0.58114924, 0.41885076]]),
#  array([[0.48741987, 0.51258013]]),
#  array([[0.58913628, 0.41086372]]),
#  array([[0.15981395, 0.84018605]]),
#  array([[0.27064177, 0.72935823]]),
#  array([[0.36292352, 0.63707648]]),
#  array([[0.9094109, 0.0905891]]),
#  array([[0.14766147, 0.85233853]]),
#  array([[0.87733783, 0.12266217]]),
#  array([[0.06012532, 0.93987468]]),
#  array([[0.47623389, 0.52376611]]),
#  array([[0.26165727, 0.73834273]]),
#  array([[0.14690305, 0.85309695]]),
#  array([[0.29682867, 0.70317133]]),
#  array([[0.1391915, 0.8608085]]),
#  array([[0.81481009, 0.18518991]]),
#  array([[0.85937511, 0.14062489]]),
#  array([[0.62099628, 0.37900372]]),
#  array([[0.06012532, 0.93987468]]),
#  array([[0.34858008, 0.65141992]]),
#  array([[0.90939216, 0.09060784]]),
#  array([[0.31544303, 0.68455697]]),
#  array([[0.46150667, 0.53849333]]),
#  array([[0.52914606, 0.47085394]]),
#  array([[0.06208604, 0.93791396]]),
#  array([[0.28042684, 0.71957316]]),
#  array([[0.422396, 0.577604]]),
#  array([[0.12073058, 0.87926942]]),
#  array([[0.60578501, 0.39421499]]),
#  array([[0.60210601, 0.39789399]]),
#  array([[0.08187092, 0.91812908]]),
#  array([[0.63807807, 0.36192193]]),
#  array([[0.09691455, 0.90308545]]),
#  array([[0.77517451, 0.22482549]]),
#  array([[0.07406058, 0.92593942]]),
#  array([[0.72092437, 0.27907563]]),
#  array([[0.45215862, 0.54784138]]),
#  array([[0.52194297, 0.47805703]]),
#  array([[0.09173591, 0.90826409]]),
#  array([[0.10266512, 0.89733488]]),
#  array([[0.34538326, 0.65461674]]),
#  array([[0.89288606, 0.10711394]]),
#  array([[0.07103742, 0.92896258]]),
#  array([[0.0777867, 0.9222133]]),
#  array([[0.31636975, 0.68363025]]),
#  array([[0.44832173, 0.55167827]]),
#  array([[0.28868438, 0.71131562]]),
#  array([[0.2195451, 0.7804549]]),
#  array([[0.72829913, 0.27170087]]),
#  array([[0.16235521, 0.83764479]]),
#  array([[0.59515264, 0.40484736]]),
#  array([[0.0626804, 0.9373196]]),
#  array([[0.26789026, 0.73210974]]),
#  array([[0.85434531, 0.14565469]]),
#  array([[0.14464686, 0.85535314]]),
#  array([[0.74228598, 0.25771402]]),
#  array([[0.22129269, 0.77870731]]),
#  array([[0.06787651, 0.93212349]]),
#  array([[0.23231605, 0.76768395]]),
#  array([[0.077235, 0.922765]]),
#  array([[0.36328417, 0.63671583]]),
#  array([[0.69610007, 0.30389993]])]

# %%
predicted[0][0],predicted[0][0][0],predicted[0][0][1]
# Out:
# (array([0.35968432, 0.64031568]), 0.3596843178717871, 0.640315682128213)

# %%
resultdf['Prob_not_getting_placed'] = np.array([predicted[i][0][0] for i in range(len(predicted))])
resultdf['Prob_getting_placed'] = np.array([predicted[i][0][1] for i in range(len(predicted))])
resultdf
# Out:
#      Gender  Specialisation  Techinal Degree  Work Experience  SSC_p  \
# 0         1               1                2                0  67.00
# 1         1               0                2                1  79.33
# 2         1               0                0                0  65.00
# 3         1               1                2                0  56.00
# 4         1               0                0                0  85.80
# ..      ...             ...              ...              ...    ...
# 210       1               0                0                0  80.60
# 211       1               0                2                0  58.00
# 212       1               0                0                1  67.00
# 213       0               1                0                0  74.00
# 214       1               1                0                0  62.00
#
#      High School_p  Degree_p  MBA_p  Actual  Predicted  \
# 0            91.00     58.00  58.80       1          1
# 1            78.33     77.48  66.28       1          1
# 2            68.00     64.00  57.80       1          1
# 3            52.00     52.00  59.43       0          0
# 4            73.60     73.30  55.50       1          1
# ..             ...       ...    ...     ...        ...
# 210          82.00     77.60  74.49       1          1
# 211          60.00     72.00  53.62       1          1
# 212          67.00     73.00  69.72       1          1
# 213          66.00     58.00  60.23       1          1
# 214          58.00     53.00  60.22       0          0
#
#      Prob_not_getting_placed  Prob_getting_placed
# 0                   0.359684             0.640316
# 1                   0.062805             0.937195
# 2                   0.279289             0.720711
# 3                   0.895037             0.104963
# 4                   0.063909             0.936091
# ..                       ...                  ...
# 210                 0.067877             0.932123
# 211                 0.232316             0.767684
# 212                 0.077235             0.922765
# 213                 0.363284             0.636716
# 214                 0.696100             0.303900
#
# [215 rows x 12 columns]

# %%
# saving the model

import pickle
file = open('campusplacementpredictor.pkl','wb')
pickle.dump(rf,file)
file.close()

# %% [markdown]
# ### Conclusions
#
#
#  + 16 records were missclassified,resulting in the accuracy of 93% on testing data
#  + Random Forest model gave the best results
